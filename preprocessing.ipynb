# %%
import pandas as pd

# %%
import matplotlib.pyplot as pt

# %%
ss=pd.read_csv("50_startups.csv")

# %%
ss
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11              NaN     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
ss=ss.fillna(ss.mean())

# %%
ss
# Out:
#         R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.200000       136897.80    471784.100000    New York  192261.83
# 1   162597.700000       151377.59    443898.530000  California  191792.06
# 2   153441.510000       101145.55    407934.540000     Florida  191050.39
# 3   144372.410000       118671.85    383199.620000    New York  182901.99
# 4   142107.340000        91391.77    366168.420000     Florida  166187.94
# 5   131876.900000        99814.71    362861.360000    New York  156991.12
# 6   134615.460000       147198.87    127716.820000  California  156122.51
# 7   130298.130000       145530.06    323876.680000     Florida  155752.60
# 8   120542.520000       148718.95    311613.290000    New York  152211.77
# 9   123334.880000       108679.17    304981.620000  California  149759.96
# 10  101913.080000       110594.11    210654.978367     Florida  146121.95
# 11  100671.960000        91790.61    249744.550000  California  144259.40
# ...

# %%
ss.fillna(ss["State"].mode()[0],inplace=True)

# %%
ss.corr()
# Out:
#                  R&D Spend  Administration  Marketing Spend    Profit
# R&D Spend         1.000000        0.248629         0.728267  0.971896
# Administration    0.248629        1.000000        -0.030976  0.200717
# Marketing Spend   0.728267       -0.030976         1.000000  0.745323
# Profit            0.971896        0.200717         0.745323  1.000000

# %%
import seaborn as sns

# %%
sns.heatmap(ss.corr(),annot=True)

# %%
ss.drop("Administration",axis=1,inplace=True)

# %%
ss
# Out:
#         R&D Spend  Marketing Spend       State     Profit
# 0   165349.200000    471784.100000    New York  192261.83
# 1   162597.700000    443898.530000  California  191792.06
# 2   153441.510000    407934.540000     Florida  191050.39
# 3   144372.410000    383199.620000    New York  182901.99
# 4   142107.340000    366168.420000     Florida  166187.94
# 5   131876.900000    362861.360000    New York  156991.12
# 6   134615.460000    127716.820000  California  156122.51
# 7   130298.130000    323876.680000     Florida  155752.60
# 8   120542.520000    311613.290000    New York  152211.77
# 9   123334.880000    304981.620000  California  149759.96
# 10  101913.080000    210654.978367     Florida  146121.95
# 11  100671.960000    249744.550000  California  144259.40
# 12   93863.750000    249839.440000     Florida  141585.52
# 13   91992.390000    252664.930000  California  134307.35
# 14  119943.240000    256512.920000     Florida  132602.65
# ...

# %%
sns.heatmap(ss.corr(),annot=True)

# %%
x=ss.iloc[:,0:3].values

# %%
x
# Out:
# array([[165349.2, 471784.1, 'New York'],
#        [162597.7, 443898.53, 'California'],
#        [153441.51, 407934.54, 'Florida'],
#        [144372.41, 383199.62, 'New York'],
#        [142107.34, 366168.42, 'Florida'],
#        [131876.9, 362861.36, 'New York'],
#        [134615.46, 127716.82, 'California'],
#        [130298.13, 323876.68, 'Florida'],
#        [120542.52, 311613.29, 'New York'],
#        [123334.88, 304981.62, 'California'],
#        [101913.08, 210654.97836734698, 'Florida'],
#        [100671.96, 249744.55, 'California'],
#        [93863.75, 249839.44, 'Florida'],
#        [91992.39, 252664.93, 'California'],
#        [119943.24, 256512.92, 'Florida'],
#        [114523.61, 261776.23, 'California'],
#        [78013.11, 264346.06, 'California'],
#        [94657.16, 282574.31, 'New York'],
#        [91749.16, 294919.57, 'Florida'],
#        [86419.7, 0.0, 'New York'],
#        [76253.86, 298664.47, 'California'],
#        [78389.47, 299737.29, 'New York'],
# ...

# %%
y=ss.iloc[:,-1].values

# %%
y
# Out:
# array([192261.83, 191792.06, 191050.39, 182901.99, 166187.94, 156991.12,
#        156122.51, 155752.6 , 152211.77, 149759.96, 146121.95, 144259.4 ,
#        141585.52, 134307.35, 132602.65, 129917.04, 126992.93, 125370.37,
#        124266.9 , 122776.86, 118474.03, 111313.02, 110352.25, 108733.99,
#        108552.04, 107404.34, 105733.54, 105008.31, 103282.38, 101004.64,
#         99937.59,  97483.56,  97427.84,  96778.92,  96712.8 ,  96479.51,
#         90708.19,  89949.14,  81229.06,  81005.76,  78239.91,  77798.83,
#         71498.49,  69758.98,  65200.33,  64926.08,  49490.75,  42559.73,
#         35673.41,  14681.4 ])

# %%
from sklearn.preprocessing import LabelEncoder

# %%
a=LabelEncoder()

# %%
x[:,2]=a.fit_transform(x[:,2])

# %%
x
# Out:
# array([[165349.2, 471784.1, 2],
#        [162597.7, 443898.53, 0],
#        [153441.51, 407934.54, 1],
#        [144372.41, 383199.62, 2],
#        [142107.34, 366168.42, 1],
#        [131876.9, 362861.36, 2],
#        [134615.46, 127716.82, 0],
#        [130298.13, 323876.68, 1],
#        [120542.52, 311613.29, 2],
#        [123334.88, 304981.62, 0],
#        [101913.08, 210654.97836734698, 1],
#        [100671.96, 249744.55, 0],
#        [93863.75, 249839.44, 1],
#        [91992.39, 252664.93, 0],
#        [119943.24, 256512.92, 1],
#        [114523.61, 261776.23, 0],
#        [78013.11, 264346.06, 0],
#        [94657.16, 282574.31, 2],
#        [91749.16, 294919.57, 1],
#        [86419.7, 0.0, 2],
#        [76253.86, 298664.47, 0],
#        [78389.47, 299737.29, 2],
#        [73994.56, 303319.26, 1],
#        [67532.53, 304768.73, 1],
#        [77044.01, 140574.81, 2],
#        [64664.71, 137962.62, 0],
#        [75328.87, 134050.07, 1],
#        [72107.6, 353183.81, 2],
# ...

# %%
from sklearn.preprocessing import OneHotEncoder as gg

# %%
d=gg(categorical_features=[2])

# %%
x=d.fit_transform(x).toarray()

# %%
x
# Out:
# array([[0.00000000e+00, 0.00000000e+00, 1.00000000e+00, 1.65349200e+05,
#         4.71784100e+05],
#        [1.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.62597700e+05,
#         4.43898530e+05],
#        [0.00000000e+00, 1.00000000e+00, 0.00000000e+00, 1.53441510e+05,
#         4.07934540e+05],
#        [0.00000000e+00, 0.00000000e+00, 1.00000000e+00, 1.44372410e+05,
#         3.83199620e+05],
#        [0.00000000e+00, 1.00000000e+00, 0.00000000e+00, 1.42107340e+05,
#         3.66168420e+05],
#        [0.00000000e+00, 0.00000000e+00, 1.00000000e+00, 1.31876900e+05,
#         3.62861360e+05],
#        [1.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.34615460e+05,
#         1.27716820e+05],
#        [0.00000000e+00, 1.00000000e+00, 0.00000000e+00, 1.30298130e+05,
#         3.23876680e+05],
#        [0.00000000e+00, 0.00000000e+00, 1.00000000e+00, 1.20542520e+05,
#         3.11613290e+05],
#        [1.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.23334880e+05,
# ...

# %%
x=x[:,1:]

# %%
x
# Out:
# array([[0.00000000e+00, 1.00000000e+00, 1.65349200e+05, 4.71784100e+05],
#        [0.00000000e+00, 0.00000000e+00, 1.62597700e+05, 4.43898530e+05],
#        [1.00000000e+00, 0.00000000e+00, 1.53441510e+05, 4.07934540e+05],
#        [0.00000000e+00, 1.00000000e+00, 1.44372410e+05, 3.83199620e+05],
#        [1.00000000e+00, 0.00000000e+00, 1.42107340e+05, 3.66168420e+05],
#        [0.00000000e+00, 1.00000000e+00, 1.31876900e+05, 3.62861360e+05],
#        [0.00000000e+00, 0.00000000e+00, 1.34615460e+05, 1.27716820e+05],
#        [1.00000000e+00, 0.00000000e+00, 1.30298130e+05, 3.23876680e+05],
#        [0.00000000e+00, 1.00000000e+00, 1.20542520e+05, 3.11613290e+05],
#        [0.00000000e+00, 0.00000000e+00, 1.23334880e+05, 3.04981620e+05],
#        [1.00000000e+00, 0.00000000e+00, 1.01913080e+05, 2.10654978e+05],
#        [0.00000000e+00, 0.00000000e+00, 1.00671960e+05, 2.49744550e+05],
#        [1.00000000e+00, 0.00000000e+00, 9.38637500e+04, 2.49839440e+05],
# ...

# %%
from sklearn.model_selection import train_test_split as vv

# %%
x1,x2,y1,y2=vv(x,y,test_size=0.2,random_state=0)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x1[:,2:3],y1,".")

# %%
import seaborn as sns

# %%
sns.pairplot(ss)

# %%
from sklearn.linear_model import LinearRegression

# %%
l=LinearRegression()

# %%
l.fit(x1,y1)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
ypre=l.predict(x2)

# %%
ypre
# Out:
# array([ 97744.55624888, 133231.64611224, 129305.79249121,  68976.82530703,
#        176796.05000944, 116535.39247434,  69744.12579893,  99007.40017173,
#        110213.05376908, 166404.24827115])

# %%
y2
# Out:
# array([103282.38, 144259.4 , 146121.95,  77798.83, 191050.39, 105008.31,
#         81229.06,  97483.56, 110352.25, 166187.94])

# %%
from sklearn.metrics import r2_score as r2

# %%
r2(y2,ypre)
# Out:
# 0.9231176763130143

# %%
x2.shape
# Out:
# (10, 4)

# %%
r2(y2,ypre)
# Out:
# 0.9231176763130143
